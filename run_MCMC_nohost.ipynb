# %%
import numpy as np

from modelVelocity import ModelVelocity
from logProb import log_prob
from MCMC import MCMC

#from multiprocessing import get_context
import os
os.environ["OMP_NUM_THREADS"] = "1"

# %%
#Read the measurements. 
data = np.loadtxt("data.dat")
sigma_obs = data[:,0]
sigma_obs_err = data[:,1]
r_ins = data[:,2]
r_outs = data[:,3]
sigma_Bs = data[:,4]

# %%
#Initialize the modeling object
modelv = ModelVelocity(sigma_Bs, r_ins, r_outs)

# %%
#Initial guesses. Order is n, log Mbulge, re bulge, log Mbh
x_init = np.array([4.0, 1., 1.5, 10.])

#Set the bounds.
x_min = np.array([0.50,  8., 0.25, 0.])
x_max = np.array([10.0, 12., 10.0, 11.])

#Set which parameters are fixed.
ifix  = np.zeros(x_init.shape, dtype=bool)
ifix[0] = True
ifix[1] = True
ifix[2] = True
#ifix[3] = True

# %%
#Run the MCMC
myMCMC = MCMC(x_init, x_min, x_max, modelv, log_prob, sigma_obs, sigma_obs_err, ifix=ifix)
myMCMC.runMCMC()
# Out:
# 100%|██████████| 500/500 [00:44<00:00, 11.29it/s]
# 100%|██████████| 2000/2000 [04:02<00:00,  8.26it/s]
# /Users/rjassef/Work/Mai_Liao/SMBH_fitter/MCMC.py:44: RuntimeWarning: overflow encountered in power
#   self.flat_samples_nolog[:,1] = 10.**self.flat_samples[:,1]

# %%
myMCMC.plotConvergence()

# %%
myMCMC.corner_plot()

# %%
myMCMC.best_fit()
# Out:
# (array([4.        , 1.        , 1.5       , 9.98690449]), -3.7804197062666915)

# %%
myMCMC.plot_bestfit()

# %%
myMCMC.save_flat_samples("MCMC_nohost_flatchain.txt")
